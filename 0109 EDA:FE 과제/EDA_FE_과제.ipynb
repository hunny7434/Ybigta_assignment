# %% [markdown]
# # EDA_FE 과제
# #### <font color='orange'> - 약간 매운맛

# %% [markdown]
# by YBIGTA 16기 DA Team 김지환

# %% [markdown]
# <img src='https://i.imgur.com/cqdVyfs.jpg'>
#
#
# ---
# 여러분은 Airbnb 런던 지사의 데이터 분석가입니다.
#
# 이번에 호스트들에게 적정한 방 가격을 책정해주는 프로젝트를 진행할 예정입니다.
#
# 이를 위해 기존에 런던에 있던 Airbnb 방 데이터를 분석할 것입니다.
#
# 각 문제에 대해 적절한 코드 혹은 답변을 제시해보세요.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# notebook을 실행한 브라우저에서 바로 그림을 볼 수 있게 해주는 코드. 버전에 따라 필요 없을 수도 있습니다.
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_csv('airbnb_listings.csv', index_col=0)
# Out:
# /var/folders/xm/qx6tpq9x31x7c9sbh6vl0ks40000gn/T/ipykernel_11121/1549664109.py:1: DtypeWarning: Columns (25,26,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('airbnb_listings.csv', index_col=0)

# %% [markdown]
# # EDA

# %% [markdown]
# ### 1) 전체 데이터 확인

# %% [markdown]
# - #### <font color='orange'> Q1. 상위 5개의 데이터를 확인해보세요. 컬럼 수가 많으니 모든 컬럼을 표시하도록 조정하세요. </font>

# %%
# Q1
pd.set_option('display.max_columns', None)

df.head()
# Out:
#              id  host_response_time host_response_rate host_acceptance_rate  \
# 0          2060  a few days or more                22%                  50%
# 1          2595        within a day                87%                  38%
# 2          3831      within an hour                83%                  96%
# 3          5099                 NaN                NaN                  71%
# 4          5114        within a day                50%                  NaN
# ...         ...                 ...                ...                  ...
# 50791  42890680      within an hour               100%                 100%
# 50792  42890730      within an hour               100%                  99%
# 50793  42891018                 NaN                NaN                  NaN
# 50794  42891637                 NaN                NaN                 100%
# 50795  42892717  a few days or more                 0%                 100%
#
# ...

# %% [markdown]
# ---
# ### 2) 결측치 확인

# %% [markdown]
# - #### <font color='orange'> Q2. 각 컬럼의 결측치를 확인하고, 결측치가 많은 순서대로 결측치 비율과 함께 표로 나타내보세요.
# <font color='orange'> (결측치 0개인 컬럼은 나타내지 마세요)

# %%
# Q2
missing_values = df.isnull().sum()

drop = missing_values[missing_values == 0].index
df = df.drop(columns=drop)

missing_values = df.isnull().sum()

missing_percentage = (missing_values / len(df)) * 100

missing_data = pd.DataFrame({
    '결측치 수': missing_values,
    '결측치 비율 (%)': missing_percentage
})
missing_data_sorted = missing_data.sort_values(by='결측치 수', ascending=False)
missing_data_sorted
# Out:
#                              결측치 수  결측치 비율 (%)
# jurisdiction_names           50781   99.970470
# license                      50759   99.927160
# square_feet                  50407   99.234192
# monthly_price                46119   90.792582
# weekly_price                 45411   89.398772
# host_response_rate           19006   37.416332
# host_response_time           19006   37.416332
# security_deposit             17325   34.107016
# host_acceptance_rate         14015   27.590755
# review_scores_value          11482   22.604142
# review_scores_location       11482   22.604142
# review_scores_checkin        11479   22.598236
# review_scores_accuracy       11466   22.572644
# review_scores_communication  11463   22.566738
# review_scores_cleanliness    11452   22.545082
# review_scores_rating         11431   22.503740
# reviews_per_month            10453   20.578392
# beds                           482    0.948894
# bedrooms                        77    0.151587
# ...

# %%
#Q2
# Out:
# id                                      0
# host_response_time                  19006
# host_response_rate                  19006
# host_acceptance_rate                14015
# host_is_superhost                       5
# host_listings_count                     5
# host_total_listings_count               5
# host_verifications                      5
# host_has_profile_pic                    5
# host_identity_verified                  5
# neighborhood                            0
# latitude                                0
# longitude                               0
# is_location_exact                       0
# property_type                           0
# room_type                               0
# accommodates                            0
# bathrooms                              54
# bedrooms                               77
# beds                                  482
# bed_type                                0
# amenities                               0
# ...

# %% [markdown]
# - #### <font color='orange'> Q3. 결측치가 있는 컬럼과 결측치 비율을 보기쉽게 그래프로 나타내 보세요.

# %%
# Q3
missing_percentage_sorted = missing_percentage[missing_data_sorted.index]
plt.figure(figsize=(10, 6))
plt.bar(missing_data_sorted.index, missing_percentage_sorted)
#plt.xlabel('컬럼명')
plt.ylabel('missing_%')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - #### <font color='orange'> Q4. 결측치가 적은 beds 컬럼을 좀 더 자세히 살펴보겠습니다.
#   #### <font color='orange'> 'beds' 컬럼이 결측치인 데이터의 상위 5개를 출력해주세요.

# %%
# Q4

missing_beds_data = df[df['beds'].isnull()].head(5)
missing_beds_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'beds'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ---
# ### 3) 범주형 변수 확인
# <font color='gray'> - 편의를 위해 결측치가 있는 컬럼을 모두 제거하고 진행하겠습니다.

# %%
drop_col = ['jurisdiction_names', 'license', 'square_feet', 'monthly_price',
       'weekly_price', 'host_response_rate', 'host_response_time',
       'security_deposit', 'host_acceptance_rate', 'review_scores_location',
       'review_scores_value', 'review_scores_checkin',
       'review_scores_accuracy', 'review_scores_communication',
       'review_scores_cleanliness', 'review_scores_rating',
       'reviews_per_month', 'beds']

# %%
df = df.drop(columns=drop_col)

# %% [markdown]
# - #### 각 컬럼별 변수 타입 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50796 entries, 0 to 50795
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                50796 non-null  int64
#  1   host_is_superhost                 50791 non-null  object
#  2   host_listings_count               50791 non-null  float64
#  3   host_total_listings_count         50791 non-null  float64
#  4   host_verifications                50791 non-null  object
#  5   host_has_profile_pic              50791 non-null  object
#  6   host_identity_verified            50791 non-null  object
#  7   neighborhood                      50796 non-null  object
#  8   latitude                          50796 non-null  float64
#  9   longitude                         50796 non-null  float64
#  10  is_location_exact                 50796 non-null  object
# ...

# %% [markdown]
# - #### <font color='orange'> Q5. Room Type 에는 어떤 것들이 있는지 살펴보겠습니다.
# #### <font color='orange'> room_type의 종류별 갯수에 대한 그래프를 그려주세요.

# %%
# Q5
room_type_counts = df['room_type'].value_counts()
room_type_counts.plot(kind='bar')
plt.show()

# %% [markdown]
# - #### <font color='orange'> Q6. 위 그래프의 세로축이 갯수가 아닌 비율을 나타내도록 재구성해보세요.

# %%
# Q6
room_type_percentage = df['room_type'].value_counts(normalize=True)
room_type_percentage.plot(kind='bar')
plt.show()

# %% [markdown]
# - #### <font color='orange'> Q7. 각 지역별로 room_type의 비율이 어땠는 지 알고 싶습니다.
# #### <font color='orange'> 아래 그래프와 같이 각 지역별로 room_type의 갯수가 어땠는지 보여주세요.

# %%
# Q7
room_type_neighborhood = df.groupby(['neighborhood'])['room_type'].value_counts()
room_type_neighborhood.plot(kind='bar')
plt.show()

# %% [markdown]
# - #### <font color='orange'> Q8. 각 지역별로 가격의 분포가 어떤지 알고 싶습니다.
# #### <font color='orange'> 아래 그래프와 같이 각 지역별로 가격의 분포를 보여주세요.

# %%
# Q8
# plt.figure() 여기부턴 직접 사이즈 조절해보세요
sns.scatterplot(data=df, x='neighborhood', y='price', alpha=0.5, palette='viridis')
# Out:
# /var/folders/xm/qx6tpq9x31x7c9sbh6vl0ks40000gn/T/ipykernel_11121/563398987.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='neighborhood', y='price', alpha=0.5, palette='viridis')
# <Axes: xlabel='neighborhood', ylabel='price'>

# %% [markdown]
# - #### <font color='orange'> Q9. 위 그래프들로부터 알 수 있는 사실은 무엇인가요? 그 이유는 무엇이라고 생각하시나요?

# %% [markdown]
# 맨허튼의 속소가 상대적으로 비싸고, Staten Island의 속소가 상대적으로 저렴하다는 점, 맨하튼의 숙소가 많고 Staten Island의 숙소가 상대적으로 적다는 점을 고려하였을 때, 맨허튼은 사람들이 자주 찾는 관광지이며, Staten Island는 상대적으로 사람들이 적게 방문하는 관광지임을 알 수 있습니다. 또한 맨허튼의 숙소가 Entire House의 비중이 높은 것으로 보아 가족 단위의 관광객이 많이 찾을 것으로 예상할 수 있습니다.

# %%
# Q9

# %% [markdown]
# ---
# ### 4) 연속형 변수 확인

# %% [markdown]
# - #### <font color='orange'> Q10. 각 방의 수용가능인원의 분포를 알고싶습니다.
# #### <font color='orange'> 'accommodates' 칼럼에 대한 히스토그램을 그려주세요.

# %%
# Q10
plt.figure(figsize=(10, 6))
plt.hist(df['accommodates'], bins=20)
plt.show()

# %% [markdown]
# - #### <font color='orange'> Q11. 각 방의 가격의 분포를 알고 싶습니다.
# #### <font color='orange'> 'price' 칼럼에 대한 히스토그램을 그려주세요. 범위는 0~1000까지만 보여주세요.

# %%
# Q11
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=50, range=(0, 1000))
plt.show()

# %% [markdown]
# * **굵은 텍스트** Q3 hint
#
# <font color='white'> x축 라벨을 45도 기울이려면 plot.set_xticklabels()을 찾아보세요. </font>

# %% [markdown]
# ---
# ### 5) Feature Engineering

# %% [markdown]
# feature에 대한 전처리를 하기 이전에 결측치가 있는 column을 모두 제거했는데, 다시 초기 상태로 되돌리고 진행하겠습니다.

# %%
df = pd.read_csv('airbnb_listings.csv', index_col=0)
# Out:
# /var/folders/xm/qx6tpq9x31x7c9sbh6vl0ks40000gn/T/ipykernel_11121/1549664109.py:1: DtypeWarning: Columns (25,26,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('airbnb_listings.csv', index_col=0)

# %% [markdown]
# - #### <font color='orange'> Q12. 결측치에 대한 처리를 하고 싶습니다.
# #### <font color='orange'> 주어진 모든 column들에 대하여 결측치가 25%이상인 경우에는 column을 drop하고 10%이상 25%미만인 경우에는 결측치가 있는 row만 drop하고, 10%미만인 경우에는 중앙값으로 대체해주세요.

# %%
#Q12
missing_values = df.isnull().sum()

missing_percentage = (missing_values / len(df))

for column in df.columns:
    if missing_percentage[column] >= 0.25: 
            df = df.drop(column, axis=1)
    elif 0.1 <= missing_percentage[column] < 0.25:
        if pd.api.types.is_numeric_dtype(df[column]):
            df = df.dropna(subset=[column])
    else:
        if pd.api.types.is_numeric_dtype(df[column]):
            df[column].fillna(df[column].median(), inplace=True)
df
# Out:
#       host_is_superhost  host_listings_count  host_total_listings_count  \
# 1                     f                  6.0                        6.0
# 2                     f                  1.0                        1.0
# 3                     f                  1.0                        1.0
# 4                     f                  3.0                        3.0
# 5                     f                  1.0                        1.0
# ...                 ...                  ...                        ...
# 50490                 f                  0.0                        0.0
# 50526                 f                  1.0                        1.0
# 50598                 f                  0.0                        0.0
# 50650                 f                 10.0                       10.0
# 50694                 f                  0.0                        0.0
#
#                                       host_verifications host_has_profile_pic  \
# ...

# %% [markdown]
# - #### <font color='orange'> Q13. 앞서 진행한 EDA를 바탕으로 FE를 진행하고자 합니다..
# #### <font color='orange'> 총 3개의 FE를 진행하시고, 해당 FE를 진행한 이유에 대해 **간단히** 작성해주세요.

# %%
#Q13-1)
df['price_per_person'] = df['price'] / df['accommodates']

# %% [markdown]
# Q13-1)
# 사용 인원별 인당 가격을 측정하여, 전체 가격 이외에 인당 가격을 볼 수 있게 하여 숙소 선택에 있어 더 정확한 가격 지표를 제공할 수 있습니다.

# %%
#Q13-2)
df['weekly_price'].fillna(df['price'] * 7, inplace=True)
df['monthly_price'].fillna(df['price'] * 30, inplace=True)
# Out:
#              id  host_response_time host_response_rate host_acceptance_rate  \
# 0          2060  a few days or more                22%                  50%
# 1          2595        within a day                87%                  38%
# 2          3831      within an hour                83%                  96%
# 3          5099                 NaN                NaN                  71%
# 4          5114        within a day                50%                  NaN
# ...         ...                 ...                ...                  ...
# 50791  42890680      within an hour               100%                 100%
# 50792  42890730      within an hour               100%                  99%
# 50793  42891018                 NaN                NaN                  NaN
# 50794  42891637                 NaN                NaN                 100%
# 50795  42892717  a few days or more                 0%                 100%
#
# ...

# %% [markdown]
# Q13-2)
# weekly_price가 결측치인 경우는 주간 숙박 할인이 없다고 가정하고 price*7을, monthly_price가 결측치인 경우는 월간 숙박 할인이 없다고 가정하고 price*30을 넣어줍니다.

# %%
#Q13-3)
df['has_air_conditioning'] = df['amenities'].str.contains('Air conditioning').astype(int)
# Out:
#      id  host_response_time host_response_rate host_acceptance_rate  \
# 0  2060  a few days or more                22%                  50%
# 1  2595        within a day                87%                  38%
# 2  3831      within an hour                83%                  96%
# 3  5099                 NaN                NaN                  71%
# 4  5114        within a day                50%                  NaN
#
#   host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                 f                  0.0                        0.0
# 1                 f                  6.0                        6.0
# 2                 f                  1.0                        1.0
# 3                 f                  1.0                        1.0
# 4                 f                  3.0                        3.0
#
#                                   host_verifications host_has_profile_pic  \
# ...

# %% [markdown]
# Q13-3)
# 여름철 에어컨도 없는 숙소에 지냈던 저의 경험에 따른 FE로, 여름철에 숙소를 고를 때 Air conditioning이 없는 거지같은 숙소는 거를 수 있는 column을 추가해보았습니다.

# %% [markdown]
# ---
#
# EDA는 언뜻보면 불필요해 보이는 과정이지만, 실제 데이터를 다룰때 매우매우 중요한 과정입니다.
#
# 때문에 기본적인 개념 및 시각화 방법은 숙지해 두시는 것이 좋습니다!
#
# 또한 FE를 통하여 여러분들이 실제로 필요한 모델에 필요한 변수 형태를 띄게 변수를 바꿔주는 과정 또한 필수적인 과정이니, 다양한 방법의 FE 역시 숙지해 두시는 게 좋습니다
#
# ---

# %% [markdown]
# * Q2 hint
#
# <font color='white'> df의 null의 개수를 센 다음에, ".to_frame()" 을 써보세요.
# 1. missingnum=df.isnull().sum()으로 우선 결측치확인
# 2. missingnum>0조건 만족시키는 missingnum 확인하기
# 3. missingnum을 column으로 하는 새로운 df생성
# 4. 새로운 df sort하기
# 5. missing_%를 새로운 column으로 추가
#
# </font>

# %% [markdown]
# * Q3 hint
#
#
# <font color='white'> x축 라벨을 45도 기울이려면 plot.set_xticklabels()을 찾아보세요. </font>
