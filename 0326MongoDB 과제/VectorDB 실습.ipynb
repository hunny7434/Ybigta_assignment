# %% [markdown]
# # 1. ChromaDB 설치 및 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.6.4)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 58.3 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.110.1-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 12.2 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.10.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 83.8 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 84.0 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 7.0 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.62.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 56.1 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.4)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.9 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 9.2 MB/s eta 0:00:00
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.4.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<=7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.9 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 32.0 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 52.6 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.9 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.18.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=bd0dbdbcd826d073c1b3d3e146966c13977e128e9750c2610772dafcfb280db1
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, python-dotenv, pulsar-client, overrides, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.1.0
#     Uninstalling importlib_metadata-7.1.0:
#       Successfully uninstalled importlib_metadata-7.1.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.4.24 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.1 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-7.0.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.1 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-instrumentation-0.45b0 opentelemetry-instrumentation-asgi-0.45b0 opentelemetry-instrumentation-fastapi-0.45b0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 opentelemetry-util-http-0.45b0 orjson-3.10.0 overrides-7.7.0 posthog-3.5.0 pulsar-client-3.4.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.37.2 uvicorn-0.29.0 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %%
import chromadb
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. 데이터 불러오기
# - 데이터 출처 : https://www.kaggle.com/datasets/ahbab911/top-250-korean-dramas-kdrama-dataset?ref=breezymind.com

# %%
import pandas as pd
data_path = "/content/drive/MyDrive/kdrama.csv"

df = pd.read_csv(data_path)
filter_df = df.drop(["Aired Date","Aired On","Duration","Content Rating","Production companies", "Rank"], axis=1);

# %% [markdown]
# # 3. VectorDB

# %% [markdown]
# ## 3-1. Client

# %%
client = chromadb.PersistentClient()

# %% [markdown]
# ## 3-2. Collection
# - Collection : embedding vector, document, metadata 등을 저장하는 곳
# - metadata : 필터링을 위한 추가 정보 등을 저장하는 딕셔너리
#   - 딕셔너리 키를 "hnsw:space"로 설정하여, embedding space의 distance method를 변경할 수 있음 (기본값=L2)

# %%
collection = client.get_or_create_collection(
    name="k-drama",
    metadata={"hnsw:space": "cosine"}
)

# %% [markdown]
# ## 3-3. DataFrame to VectorDB

# %%
ids = []        # index
doc_meta = []   # metadata
documents = []  # vectors converted from text data

for idx in range(len(filter_df)):
    item = filter_df.iloc[idx]

    id = item['Name'].lower().replace(' ','-')
    document = f"{item['Name']} : {item['Synopsis']} : {str(item['Cast']).strip().lower()} : {str(item['Genre']).strip().lower()}"
    meta = {
        "rating" : item['Rating']
    }

    ids.append(id)
    doc_meta.append(meta)
    documents.append(document)

# %%
# Save to Database (VectorDB)
collection.add(
    documents=documents,
    metadatas=doc_meta,
    ids=ids
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 70.9MiB/s]

# %% [markdown]
# # 4. Query

# %%
collection.query(
    query_texts=["medical drama about doctors"],
    n_results=5,
)
# Out:
# {'ids': [['doctor-john',
#    'dr.-romantic-2',
#    'hospital-playlist',
#    'doctor-prisoner',
#    "god's-quiz:-reboot"]],
#  'distances': [[0.3436622619628906,
#    0.45732051134109497,
#    0.4621430039405823,
#    0.4815513491630554,
#    0.5326414392990194]],
#  'metadatas': [[{'rating': 8.5},
#    {'rating': 8.7},
#    {'rating': 9.1},
#    {'rating': 8.4},
#    {'rating': 8.3}]],
#  'embeddings': None,
#  'documents': [['Doctor John : “Doctor John” is a medical drama about doctors specializing in pain management. In a refreshing take on the genre, “Doctor John” will portray the doctors’ search for the cause of their patients’ mysterious pain as a thrilling chase, almost like a detective hunting down the perpetrator behind an unsolved crime.  : ji sung, lee se young, lee kyu hyung, hwang hee, jung min ah, kwon hwa woon : mystery,  romance,  life,  medical',
#    'Dr. Romantic 2 : A “real doctor” story set in a small, humble hospital called Doldam Hospital. It is a story about people who meet Kim Sa Bu, a genius doctor, and discover “real romance.” : han seok kyu, ahn hyo seop, lee sung kyung, kim joo heon, shin dong wook, so ju yeon : romance,  drama,  medical,  melodrama',
#    "Hospital Playlist : The stories of people going through their days that are seemingly ordinary but actually special, at the hospital, a place known as the microcosm of life, where someone is being born and someone's life meets their ending. The five doctors are long-time friends of 20 years who started their undergrad in 1999 in the same medical school and now are colleagues in the same hospital and have a band together. : jo jung suk, yoo yeon seok, jung kyung ho, kim dae myung, jeon mi do, shin hyun bin : friendship,  romance,  life,  medical",
#    'Doctor Prisoner : Doctor Prisoner centers around an ace doctor in a university hospital’s emergency care center, a skilled professional who treats his patients with full devotion and without discrimination. However, his medical license gets suspended as a result of a medical malpractice incident that arises when the hospital board director causes a ruckus. He then gets his certificate as a medical internist and applies to work at a prison, where his plan is to cozy up to all the bigshots there—business tycoons, celebrities caught for doing drugs, sports stars guilty of gambling—and to win allies, with the ultimate goal of getting revenge against the hospital that ousted him. To do so, he’ll get rid of the existing prison chief doctor and claim the spot for himself. : namkoong min, kwon na ra, kim byung chul, choi won young, lee da in, jin hee kyung : thriller, law, crime, medical',
#    "God's Quiz: Reboot : This is a drama about elite doctors and forensic scientists investigating mysterious deaths and solving mysteries related to rare diseases. Han Jin Woo is the tortured medical genius with a miracle brain that has been through its share of trouble. After he gets involved in an unexpected case, he returns to the medical examiner office for the first time in 4 years. : ryu deok hwan, yoon joo hee, park  hyo joo, park joon myun, kim ki doo, kim jae won : mystery, medical"]],
#  'uris': None,
#  'data': None}

# %%
collection.query(
    query_texts=["time-travel drama"],
    n_results=5,
)
# Out:
# {'ids': [['365',
#    'nine:-nine-times-time-travel',
#    'circle',
#    'because-this-is-my-first-life',
#    'one-ordinary-day']],
#  'distances': [[0.5034234523773193,
#    0.5676982998847961,
#    0.5819253921508789,
#    0.5891983509063721,
#    0.6088154911994934]],
#  'metadatas': [[{'rating': 8.6},
#    {'rating': 8.4},
#    {'rating': 8.5},
#    {'rating': 8.5},
#    {'rating': 8.5}]],
#  'embeddings': None,
#  'documents': [['365 : A story where ten people get the chance to go back in time by one year, but unexpectedly mysterious situations start to arise when their fates are changed and twisted in the process. : lee joon hyuk, nam ji hyun, kim jee soo, lee sung wook, yoon joo sang, ahn seung gyun : thriller,  mystery,  drama,  fantasy',
#    'Nine: Nine Times Time Travel : Park Sun Woo works as an anchorman at a TV broadcasting station. He is in love with news reporters Joo Min Young, who is bright and honest. Park Sun Woo then obtains 9 incense items, which allows him to go back 20 years in time. Sun Woo travels to the past in an attempt to keep his family safe in order to change the world he lives in today. However, this is not without consequences for his actions in the past affects the lives of many in the present, including his crush. : lee jin wook, lee seung joon, jo yoon hee, oh min suk, lee yi kyung, jo min ah : mystery, romance, supernatural',
#    'Circle : Taking place in both the present year 2017 and in the year 2037, when people believe that their future depends on humans controlling and regulating their emotions, this drama is a sci-fi mystery. When alien visitors arrive on Earth, humans learn new skills from them and take advantage of them; what ensues is a story of alliance, resistance, and love. Each episode will contain two shorter stories, the first part set in 2017 and called “Beta Project,” with the second set in 2037 and called “Grand New World.” : yeo jin goo, kim kang woo, gong seung yeon, lee gi kwang, ahn woo yeon, seo hyun chul : thriller, mystery, sci-fi',
#    'Because This Is My First Life : A house-poor man and homeless woman become housemates in a drama that examines the institution of marriage and the problems that young people face today. : jung so min, lee min ki, esom, park byung eun, kim ga eun, kim min seok : comedy,  romance,  life,  drama',
#    "One Ordinary Day : A drama that explores the criminal justice system from an extremely popular perspective through the fierce story of two men surrounding the murder of a woman. Hyun Soo, an ordinary college student, suddenly becomes the primary suspect in a murder case. Shin Joong Han is the only lawyer willing to help Kim Hyun Soo. Having just barely passed law school, Shin Joong Han's involvement in Kim Hyun Soo's case eventually takes his unremarkable life to new heights. : kim soo hyun, cha seung won, lee seol, kim shin rok, kim hong pa, kim sung gyu : thriller, mystery, law, crime"]],
#  'uris': None,
#  'data': None}

# %% [markdown]
# 출처
# - https://docs.trychroma.com/getting-started
# - https://breezymind.com/vector-db-openai-response-optimize/

# %% [markdown]
# # 5. 과제
# - 아래 데이터를 이용하여 공포 영화 5개 출력하기
# - data path 변경하기!!!
# - 데이터 출처 : https://www.kaggle.com/datasets/narayan63/netflix-popular-movies-dataset

# %%
# data path 변경하기!!
hw_data_path = "/content/drive/MyDrive/netflix.csv"

hw_df = pd.read_csv(hw_data_path)

# %%
hw_filter_df = hw_df.drop(["year", "certificate", "duration", "votes"], axis=1).drop_duplicates('title');

def changeString(x):
  return x.replace('\'','').replace('[','').replace(']','').replace(', ,',',')

hw_filter_df['stars'] = hw_filter_df['stars'].apply(changeString)
hw_filter_df = hw_filter_df.iloc[:300]

# %%
hw_filter_df
# Out:
#                                 title                         genre  rating  \
# 0                           Cobra Kai         Action, Comedy, Drama     8.5
# 1                           The Crown     Biography, Drama, History     8.7
# 2                    Better Call Saul                  Crime, Drama     8.9
# 3                       Devil in Ohio        Drama, Horror, Mystery     5.9
# 4              Cyberpunk: Edgerunners  Animation, Action, Adventure     8.6
# ..                                ...                           ...     ...
# 296                       Incantation               Horror, Mystery     6.2
# 297                Queen of the South          Action, Crime, Drama     8.0
# 298                           Godless        Action, Drama, Western     8.3
# 299  Fullmetal Alchemist: Brotherhood  Animation, Action, Adventure     9.1
# 300                       Ray Donovan                  Crime, Drama     8.3
#
#                                            description  \
# 0    Decades after their 1984 All Valley Karate Tou...
# 1    Follows the political rivalries and romance of...
# 2    The trials and tribulations of criminal lawyer...
# 3    When a psychiatrist shelters a mysterious cult...
# 4    A Street Kid trying to survive in a technology...
# ..                                                 ...
# 296  Six years ago, Li Ronan was cursed after break...
# 297  Teresa flees Mexico after her drug-runner boyf...
# 298  In the 1880s American West, murderous outlaw g...
# 299  Two brothers search for a Philosopher's Stone ...
# 300  Ray Donovan, a professional "fixer" for the ri...
#
#                                                  stars
# 0    Ralph Macchio, William Zabka, Courtney Henggel...
# 1    Claire Foy, Olivia Colman, Imelda Staunton, Ma...
# 2    Bob Odenkirk, Rhea Seehorn, Jonathan Banks, Pa...
# 3    Emily Deschanel, Sam Jaeger, Gerardo Celasco, ...
# 4     Zach Aguilar, Kenichiro Ohashi, Emi Lo, Aoi Yûki
# ..                                                 ...
# 296  Kevin Ko, | ,     Stars:, Hsuan-yen Tsai, Ying...
# 297  Alice Braga, Hemky Madera, Peter Gadiot, Veron...
# 298  "Jack OConnell, ", Michelle Dockery, Scoot McN...
# 299  Kent Williams, Iemasa Kayumi, Matthew Leonhart...
# 300  Liev Schreiber, Eddie Marsan, Dash Mihok, Pooc...
#
# [300 rows x 5 columns]

# %% [markdown]
# 여기서부터 코드 입력

# %%
import chromadb
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd

client = chromadb.PersistentClient()

hw_collection = client.get_or_create_collection(
    name="netflix",
    metadata={"hnsw:space": "cosine"}
)

hw_ids = []        # index
hw_doc_meta = []   # metadata
hw_documents = []  # vectors converted from text data

for idx in range(len(hw_filter_df)):
    item = hw_filter_df.iloc[idx]

    id = item['title'].lower().replace(' ','-')
    document = f"{item['title']} : {item['description']} : {str(item['stars']).strip().lower()} : {str(item['genre']).strip().lower()}"
    meta = {
        "rating" : item['rating']
    }

    hw_ids.append(id)
    hw_doc_meta.append(meta)
    hw_documents.append(document)

hw_collection.add(
    documents=hw_documents,
    metadatas=hw_doc_meta,
    ids=hw_ids
)

hw_collection.query(
    query_texts=["horror"],
    n_results=5
)
# Out:
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: cobra-kai
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-crown
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: better-call-saul
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: devil-in-ohio
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: cyberpunk:-edgerunners
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-sandman
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: rick-and-morty
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: breaking-bad
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-imperfects
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: blonde
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: stranger-things
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: end-of-the-road
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-walking-dead
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: glass-onion:-a-knives-out-mystery
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: do-revenge
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: i-came-by
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: no-limit
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 1899
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: peaky-blinders
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: fate:-the-winx-saga
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-lord-of-the-rings:-the-fellowship-of-the-ring
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: grey's-anatomy
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: supernatural
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: american-horror-story
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-accidental-narco
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: ncis
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: friends
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: shameless
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: modern-family
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: ozark
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: echoes
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-gray-man
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: me-time
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: suits
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: vikings
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-witcher
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-blacklist
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: seinfeld
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: lucifer
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-umbrella-academy
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-last-kingdom
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: partner-track
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: love-in-the-villa
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: black-mirror
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: brooklyn-nine-nine
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: squid-game
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: gilmore-girls
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: outlander
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: ófærð
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: never-have-i-ever
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: attack-on-titan
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: manifest
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: locke-&-key
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: day-shift
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: dark
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: guillermo-del-toro's-pinocchio
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: sex-education
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-lord-of-the-rings:-the-return-of-the-king
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-vampire-diaries
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: virgin-river
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: family-guy
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: fargo
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: animal-kingdom
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: diario-de-un-gigoló
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: how-i-met-your-mother
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-school-for-good-and-evil
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: heartbreak-high
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: wednesday
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: community
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: daredevil
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: blue-bloods
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: bee-and-puppycat
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: loving-adults
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: schitt's-creek
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: sing-2
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: rrr
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: arcane
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-lørenskog-disappearance
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-lord-of-the-rings:-the-two-towers
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: all-quiet-on-the-western-front
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: mr.-harrigan's-phone
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: american-psycho
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-hobbit:-an-unexpected-journey
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: kleo
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: riverdale
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: sons-of-anarchy
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: mad-men
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-flash
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: archer
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: dahmer---monster:-the-jeffrey-dahmer-story
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: mr.-robot
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: that-'70s-show
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: you
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: look-both-ways
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 365-days
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: i-used-to-be-famous
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: titanic
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: bridgerton
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: sherlock
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: dexter
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: new-girl
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-expanse
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: purple-hearts
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-gentlemen
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: the-good-doctor
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: downton-abbey
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: extraordinary-attorney-woo
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: smallville
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: star-trek:-the-next-generation
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: bojack-horseman
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: love,-death-&-robots
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: money-heist
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: orange-is-the-new-black
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: jurassic-park
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: prison-break
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID
#  'documents': [['American Horror Story : An anthology series centering on different characters and locations, including a house with a murderous past, an insane asylum, a witch coven, a freak show circus, a haunted hotel, a possessed farmhouse, a cult, the apocalypse, a slasher summer camp, and a bleak beach town and desert valley. : lady gaga, kathy bates, angela bassett, sarah paulson : drama, horror, sci-fi',
#    'It : In the summer of 1989, a group of bullied kids band together to destroy a shape-shifting monster, which disguises itself as a clown and preys on the children of Derry, their small Maine town. : andy muschietti, | ,     stars:, bill skarsgård, jaeden martell, finn wolfhard, sophia lillis : horror',
#    'From : Unravel the mystery of a city in middle U.S.A. that imprisons everyone who enters. As the residents struggle to maintain a sense of normalcy and seek a way out, they must also survive the threats of the surrounding forest. : scott mccord, harold perrineau, catalina sandino moreno, eion bailey : drama, horror, mystery',
#    "Devil in Ohio : When a psychiatrist shelters a mysterious cult escapee, her world is turned upside down as the girl's arrival threatens to tear her own family apart. : emily deschanel, sam jaeger, gerardo celasco, madeleine arthur : drama, horror, mystery",
#    "Evil : A skeptical clinical psychologist joins a priest-in-training and a blue collar contractor as they investigate supposed abnormal events, including, demonic possession, and other extraordinary occurrences to see if there's a scientific explanation or if something truly supernatural's at work. : katja herbers, mike colter, aasif mandvi, michael emerson : crime, drama, horror"]],
#  'uris': None,
#  'data': None}

# %%
## your code
horror_movies = hw_filter_df[hw_filter_df['genre'].str.contains('Horror')]
horror_movies.head(5)
# Out:
#                title                    genre  rating  \
# 3      Devil in Ohio   Drama, Horror, Mystery     5.9
# 5        The Sandman   Drama, Fantasy, Horror     7.8
# 10   Stranger Things   Drama, Fantasy, Horror     8.7
# 12  The Walking Dead  Drama, Horror, Thriller     8.1
# 17              1899   Drama, History, Horror     9.6
#
#                                           description  \
# 3   When a psychiatrist shelters a mysterious cult...
# 5   Upon escaping after decades of imprisonment by...
# 10  When a young boy disappears, his mother, a pol...
# 12  Sheriff Deputy Rick Grimes wakes up from a com...
# 17  Multinational immigrants traveling from the ol...
#
#                                                 stars
# 3   Emily Deschanel, Sam Jaeger, Gerardo Celasco, ...
# 5   Tom Sturridge, Boyd Holbrook, Patton Oswalt, V...
# 10  Millie Bobby Brown, Finn Wolfhard, Winona Ryde...
# 12  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 17  Ben Ashenden, Aneurin Barnard, Emily Beecham, ...

# %% [markdown]
# ## 과제 답안 예시

# %%
hw_collection = client.get_or_create_collection(
    name="netflix",
    metadata={"hnsw:space": "cosine"}
)

hw_ids = []        # index
hw_doc_meta = []   # metadata
hw_documents = []  # vectors converted from text data

for idx in range(len(hw_filter_df)):
    item = hw_filter_df.iloc[idx]

    id = item['title'].lower().replace(' ','-')
    document = f"{item['title']} : {item['description']} : {str(item['stars']).strip().lower()} : {str(item['genre']).strip().lower()}"
    meta = {
        "rating" : item['rating']
    }

    hw_ids.append(id)
    hw_doc_meta.append(meta)
    hw_documents.append(document)

hw_collection.add(
    documents=hw_documents,
    metadatas=hw_doc_meta,
    ids=hw_ids
)

hw_collection.query(
    query_texts=["horror film"],
    n_results=5,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e7ce03601e04> in <cell line: 1>()
# ----> 1 import chromadb
#       2 import warnings
#       3 warnings.filterwarnings(action='ignore')
#       4
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'chromadb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
